# %%
import pandas as pd
import numpy as np
data =  pd.read_json("clients.json")
data.head()
# Out:
#    identifiant                      email               nom genre
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
data['email']
# Out:
# 0            LaurentDagenais@rhyta.com
# 1                GuyMarois@fleckens.hu
# 2            BeaufortLesage@einrot.com
# 3            RussellDurand@armyspy.com
# 4                 AlexisRiel@rhyta.com
#                     ...
# 223    ClaudeDandonneau@jourrapide.com
# 224      ApollineMichaud@superrito.com
# 225         PascalineBeaudry@rhyta.com
# 226       FleurCaouette@jourrapide.com
# 227        FrancisMasse@jourrapide.com
# Name: email, Length: 228, dtype: object

# %%
variables = ['email', "nom"]
data[variables]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_444\861413367.py in <module>
#       1 variables = ['email', "nom"]
#       2 data[variables]
# ----> 3 type(data(["email"]))
#
# TypeError: 'DataFrame' object is not callable

# %%
data["identifiant"] = data["identifiant"]*100
data.head()
# Out:
#    identifiant                      email  nom genre
# 0            0  LaurentDagenais@rhyta.com    1     M
# 1        10000      GuyMarois@fleckens.hu    1     M
# 2        20000  BeaufortLesage@einrot.com    1     M
# 3        30000  RussellDurand@armyspy.com    1     M
# 4        40000       AlexisRiel@rhyta.com    1     M

# %%
data["identifiant"] = np.random.randint(1,1000, data.shape[0])
data.head()
# Out:
#    identifiant                      email               nom genre
# 0          246  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1          135      GuyMarois@fleckens.hu        Guy Marois     M
# 2          289  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3          851  RussellDurand@armyspy.com    Russell Durand     M
# 4          481       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
data["id"] = data["identifiant"] + 1000
data.head()
# Out:
#    identifiant                      email               nom genre    id
# 0          246  LaurentDagenais@rhyta.com  Laurent Dagenais     M  1246
# 1          135      GuyMarois@fleckens.hu        Guy Marois     M  1135
# 2          289  BeaufortLesage@einrot.com   Beaufort Lesage     M  1289
# 3          851  RussellDurand@armyspy.com    Russell Durand     M  1851
# 4          481       AlexisRiel@rhyta.com       Alexis Riel     M  1481

# %%
del data["id"]
data.head()
# Out:
#    identifiant                      email               nom genre
# 0          246  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1          135      GuyMarois@fleckens.hu        Guy Marois     M
# 2          289  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3          851  RussellDurand@armyspy.com    Russell Durand     M
# 4          481       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
data.rename(columns={'identifiant':"ide", 'email':"mail"})
# Out:
#      ide                             mail                nom genre
# 0    246        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1    135            GuyMarois@fleckens.hu         Guy Marois     M
# 2    289        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3    851        RussellDurand@armyspy.com     Russell Durand     M
# 4    481             AlexisRiel@rhyta.com        Alexis Riel     M
# ..   ...                              ...                ...   ...
# 223  715  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224  920    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225  817       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226  387     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227  562      FrancisMasse@jourrapide.com      Francis Masse     M
#
# [228 rows x 4 columns]

# %%
data.sort_values(["genre", 'nom'])
# Out:
#      identifiant                         email                 nom genre
# 13           204  AcelineHughes@jourrapide.com      Aceline Hughes     F
# 135          345     AdelaideBrousse@gustr.com    Adelaide Brousse     F
# 189          746        AdeleClavette@cuvox.de      Adele Clavette     F
# 15           628      AgateGrandbois@gustr.com     Agate Grandbois     F
# 180          937          AgnesBriard@cuvox.de        Agnes Briard     F
# ..           ...                           ...                 ...   ...
# 167          873      VerneyCourse@armyspy.com       Verney Course     M
# 127          899           VickDavid@gustr.com          Vick David     M
# 192          486   XarlesCaisse@jourrapide.com       Xarles Caisse     M
# 174          722   ZacharieDuplessis@rhyta.com  Zacharie Duplessis     M
# 100          504   ZdenekVadnais@superrito.com      Zdenek Vadnais     M
#
# [228 rows x 4 columns]

# %%
data.iloc[0,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6156\3744309515.py in <module>
# ----> 1 data.iloc[0,2]
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import numpy as np
data =  pd.read_json("clients.json")
data.head()
# Out:
#    identifiant                      email               nom genre
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
data.iloc[:10,1]
# Out:
# 0        LaurentDagenais@rhyta.com
# 1            GuyMarois@fleckens.hu
# 2        BeaufortLesage@einrot.com
# 3        RussellDurand@armyspy.com
# 4             AlexisRiel@rhyta.com
# 5            LeonLapresse@cuvox.de
# 6        OrvilleRouthier@gustr.com
# 7         AgramantPepin@dayrep.com
# 8    AiglentinaLambert@fleckens.hu
# 9       TheodoreClavet@teleworm.us
# Name: email, dtype: object

# %%
data.iloc[:10,:]
# Out:
#    identifiant                          email                 nom genre
# 0            0      LaurentDagenais@rhyta.com    Laurent Dagenais     M
# 1            1          GuyMarois@fleckens.hu          Guy Marois     M
# 2            2      BeaufortLesage@einrot.com     Beaufort Lesage     M
# 3            3      RussellDurand@armyspy.com      Russell Durand     M
# 4            4           AlexisRiel@rhyta.com         Alexis Riel     M
# 5            5          LeonLapresse@cuvox.de       Leon Lapresse     M
# 6            6      OrvilleRouthier@gustr.com    Orville Routhier     M
# 7            7       AgramantPepin@dayrep.com      Agramant Pepin     M
# 8            8  AiglentinaLambert@fleckens.hu  Aiglentina Lambert     F
# 9            9     TheodoreClavet@teleworm.us     Theodore Clavet     M

# %%
data.sort_values('nom').head()
# Out:
#      identifiant                         email               nom genre
# 13            13  AcelineHughes@jourrapide.com    Aceline Hughes     F
# 135          135     AdelaideBrousse@gustr.com  Adelaide Brousse     F
# 189          189        AdeleClavette@cuvox.de    Adele Clavette     F
# 15            15      AgateGrandbois@gustr.com   Agate Grandbois     F
# 180          180          AgnesBriard@cuvox.de      Agnes Briard     F

# %%
displt(data.iloc(0;10, :))
# Out:
#   File "C:\Users\faiss\AppData\Local\Temp\ipykernel_6156\3847181639.py", line 1
#     displt(data.iloc(0;10, :))
#                       ^
# SyntaxError: invalid syntax

# %%
data.loc[data['genre'] == 'F', :]
# Out:
#      identifiant                            email                 nom genre
# 8              8    AiglentinaLambert@fleckens.hu  Aiglentina Lambert     F
# 13            13     AcelineHughes@jourrapide.com      Aceline Hughes     F
# 15            15         AgateGrandbois@gustr.com     Agate Grandbois     F
# 17            17    PrunellaJosseaume@armyspy.com  Prunella Josseaume     F
# 18            18        YseultCharest@armyspy.com      Yseult Charest     F
# ..           ...                              ...                 ...   ...
# 221          221      JosetteBordeleau@einrot.com   Josette Bordeleau     F
# 223          223  ClaudeDandonneau@jourrapide.com   Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com    Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com   Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com      Fleur Caouette     F
#
# [118 rows x 4 columns]

# %%
data.loc[data['genre'] == 'M', :]
# Out:
#      identifiant                        email               nom genre
# 0              0    LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1              1        GuyMarois@fleckens.hu        Guy Marois     M
# 2              2    BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3              3    RussellDurand@armyspy.com    Russell Durand     M
# 4              4         AlexisRiel@rhyta.com       Alexis Riel     M
# ..           ...                          ...               ...   ...
# 217          217         GanoHetu@fleckens.hu         Gano Hetu     M
# 219          219     RoslynChalifour@cuvox.de  Roslyn Chalifour     M
# 220          220      KarelBazinet@einrot.com     Karel Bazinet     M
# 222          222     LangleyCaron@armyspy.com     Langley Caron     M
# 227          227  FrancisMasse@jourrapide.com     Francis Masse     M
#
# [110 rows x 4 columns]

# %%
data.loc[:3, 2] = 'F'
data.head()
# Out:
#    identifiant                      email               nom genre    3    2
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M    F    F
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M    F    F
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M    F    F
# 3            3  RussellDurand@armyspy.com    Russell Durand     M    F    F
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M  NaN  NaN

# %%
data.loc[data['genre'] == 'F', 'email']
# Out:
# 8        AiglentinaLambert@fleckens.hu
# 13        AcelineHughes@jourrapide.com
# 15            AgateGrandbois@gustr.com
# 17       PrunellaJosseaume@armyspy.com
# 18           YseultCharest@armyspy.com
#                     ...
# 221        JosetteBordeleau@einrot.com
# 223    ClaudeDandonneau@jourrapide.com
# 224      ApollineMichaud@superrito.com
# 225         PascalineBeaudry@rhyta.com
# 226       FleurCaouette@jourrapide.com
# Name: email, Length: 118, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data =  pd.read_csv("https://raw.githubusercontent.com/benjaminmrl/data-4452741/main/prets_final.csv')")
data.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6064\2797440183.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 data =  pd.read_csv("https://raw.githubusercontent.com/benjaminmrl/data-4452741/main/prets_final.csv')")
#       5 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
  prets = pd.read_csv('https://raw.githubusercontent.com/benjaminmrl/data-4452741/main/prets_final.csv')

prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non

# %%
plt.scatter(prets['revenu'], prets['taux_endettement'])

# %%
plt.plot(prets['revenu'], prets['taux_endettement'])

# %%
plt.scatter(prets['revenu'], prets['taux_endettement'],
          s=60, alpha =0.5, c='red', marker= 'P' )

# %%
data = prets.groupby('ville')['remboursement'].sum()
data = data.reset_index()

# %%
plt.pie(x=data['remboursement'], labels=data['ville'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2b8d84140d0>,
# ...
#  [Text(1.0735482898052735, 0.2397792098080497, 'BORDEAUX'),
#   Text(0.7559779933342196, 0.7990602440331811, 'LYON'),
#   Text(-0.22079479320563614, 1.0776129450286316, 'MARSEILLE'),
#   Text(-0.9928563505107825, 0.4735359197045252, 'NICE'),
#   Text(-0.3566773649937175, -1.0405677571889005, 'PARIS'),
#   Text(1.0582353655336645, -0.30022976390396683, 'TOULOUSE')])

# %%
plt.pie(x=data['remboursement'], labels=data['ville'], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2b8d94bc3d0>,
# ...
#  [Text(1.0735482898052735, 0.2397792098080497, 'BORDEAUX'),
#   Text(0.7559779933342196, 0.7990602440331811, 'LYON'),
#   Text(-0.22079479320563614, 1.0776129450286316, 'MARSEILLE'),
#   Text(-0.9928563505107825, 0.4735359197045252, 'NICE'),
#   Text(-0.3566773649937175, -1.0405677571889005, 'PARIS'),
#   Text(1.0582353655336645, -0.30022976390396683, 'TOULOUSE')],
#  [Text(0.58557179443924, 0.1307886598952998, '6.99%'),
#   Text(0.41235163272775605, 0.43585104219991694, '11.89%'),
#   Text(-0.12043352356671061, 0.5877888791065262, '18.66%'),
#   Text(-0.5415580093695176, 0.2582923198388319, '10.74%'),
#   Text(-0.19455128999657315, -0.5675824130121274, '42.91%'),
#   Text(0.5772192902910896, -0.1637616894021637, '8.80%')])

# %%
plt.bar(height=data['remboursement'], x=data['ville'])
# Out:
# <BarContainer object of 6 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
m = 100
X = np.linspace(0,10,m).reshape(m,1)
y = X + np.ramdom.randn(m,1)

plt.scatter(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15612\476794951.py in <module>
#       5 m = 100
#       6 X = np.linspace(0,10,m).reshape(m,1)
# ----> 7 y = X + np.ramdom.randn(m,1)
#       8
#       9 plt.scatter(X,y)
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'ramdom'

# %%
X = np.linspace(0,10,m).reshape(m,1)
y = X + np.ramdom.randn(m,1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15612\49210500.py in <module>
#       2 m = 100
#       3 X = np.linspace(0,10,m).reshape(m,1)
# ----> 4 y = X + np.ramdom.randn(m,1)
#       5
#       6 plt.scatter(X,y)
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'ramdom'
